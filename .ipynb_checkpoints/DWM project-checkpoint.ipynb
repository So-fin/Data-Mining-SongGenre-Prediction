# %%
import pandas as pd

# Read in track metadata with genre labels
tracks = pd.read_csv(r'fma-rock-vs-hiphop.csv')
tracks.head(10)
# Out:
#    track_id  bit_rate  comments        composer         date_created  \
# 0       135    256000         1             NaN  2008-11-26 01:43:26
# 1       136    256000         1             NaN  2008-11-26 01:43:35
# 2       151    192000         0             NaN  2008-11-26 01:44:55
# 3       152    192000         0             NaN  2008-11-26 01:44:58
# 4       153    256000         0  Arc and Sender  2008-11-26 01:45:00
# 5       154    256000         0  Arc and Sender  2008-11-26 01:45:04
# 6       155    192000         0             NaN  2008-11-26 01:45:10
# 7       169    192000         0   James Squeaky  2008-11-26 01:46:02
# 8       170    192000         0             NaN  2008-11-26 01:46:05
# 9       171    320000         0             NaN  2008-11-26 01:46:07
#
#          date_recorded  duration  favorites genre_top    genres  ...  \
# 0  2008-11-26 00:00:00       837          0      Rock  [45, 58]  ...
# 1  2008-11-26 00:00:00       509          0      Rock  [45, 58]  ...
# 2                  NaN       192          0      Rock      [25]  ...
# 3                  NaN       193          0      Rock      [25]  ...
# 4  2008-11-26 00:00:00       405          5      Rock      [26]  ...
# 5  2008-11-26 00:00:00       319          1      Rock      [26]  ...
# 6  2008-11-26 00:00:00       756          1      Rock      [26]  ...
# 7  2006-01-01 00:00:00       144          1      Rock      [25]  ...
# 8  2006-10-07 00:00:00       181          0      Rock      [25]  ...
# 9  2008-11-26 00:00:00        80          0      Rock      [25]  ...
#
#          information interest  language_code  \
# 0                NaN     2484             en
# 1                NaN     1948             en
# 2                NaN      701             en
# 3                NaN      637             en
# 4                NaN      354             en
# 5                NaN      242             en
# 6                NaN      268             en
# 7                NaN      815             en
# 8                NaN      468             en
# 9  <p>Unreleased</p>      582             en
#
#                                              license listens  lyricist number  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1832       NaN      0
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1498       NaN      0
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...     148       NaN      4
# 3  Attribution-NonCommercial-ShareAlike 3.0 Inter...      98       NaN     11
# 4  Attribution-NonCommercial-NoDerivatives (aka M...     424       NaN      2
# 5  Attribution-NonCommercial-NoDerivatives (aka M...     205       NaN      4
# 6  Attribution-NonCommercial-NoDerivatives (aka M...     197       NaN      0
# 7  Attribution-NonCommercial-ShareAlike 3.0 Inter...     270       NaN      1
# 8  Attribution-NonCommercial-ShareAlike 3.0 Inter...     122       NaN      2
# 9  Attribution-NonCommercial-ShareAlike 3.0 Inter...     242       NaN      2
#
#    publisher tags                       title
# 0        NaN   []                Father's Day
# 1        NaN   []  Peel Back The Mountain Sky
# 2        NaN   []                 Untitled 04
# 3        NaN   []                 Untitled 11
# 4        NaN   []          Hundred-Year Flood
# 5        NaN   []         Squares And Circles
# 6        NaN   []     Maps of the Stars Homes
# 7        NaN   []                Boss of Goth
# 8        NaN   []  Industry Standard Massacre
# 9        NaN   []     Marching as Technitions
#
# [10 rows x 21 columns]

# %%
# Read in track metrics with the features
echonest_metrics = pd.read_json(r'echonest-metrics.json',precise_float=True)
echonest_metrics.head(10)
# Out:
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2         5      0.043567      0.745566  0.701470          0.000697  0.373143
# 3        10      0.951670      0.658179  0.924525          0.965427  0.115474
# 4       134      0.452217      0.513238  0.560410          0.019443  0.096567
# 5       139      0.106550      0.260911  0.607067          0.835087  0.223676
# 6       140      0.376312      0.734079  0.265685          0.669581  0.085995
# 7       141      0.963657      0.435933  0.075632          0.345493  0.105686
# 8       142      0.662881      0.379065  0.823856          0.910266  0.088705
# 9       144      0.909011      0.443643  0.641997          0.924092  0.267669
#
#    speechiness    tempo   valence
# 0     0.159310  165.922  0.576661
# 1     0.461818  126.957  0.269240
# 2     0.124595  100.260  0.621661
# 3     0.032985  111.562  0.963590
# 4     0.525519  114.290  0.894072
# 5     0.030569  196.961  0.160267
# 6     0.039068  107.952  0.609991
# 7     0.026658   33.477  0.163950
# 8     0.079090  147.781  0.092868
# 9     0.089659  128.537  0.788251

# %%
# Merge the relevant columns of tracks and echonest_metrics
echo_tracks = echonest_metrics.merge(tracks[['genre_top', 'track_id']], on='track_id')
echo_tracks.head(10)
# Out:
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2         5      0.043567      0.745566  0.701470          0.000697  0.373143
# 3       134      0.452217      0.513238  0.560410          0.019443  0.096567
# 4       153      0.988306      0.255661  0.979774          0.973006  0.121342
# 5       154      0.970135      0.352946  0.023852          0.957113  0.113261
# 6       155      0.981657      0.142249  0.912122          0.967294  0.363510
# 7       169      0.989141      0.225978  0.722835          0.263076  0.092371
# 8       170      0.886660      0.298518  0.744333          0.920950  0.139587
# 9       171      0.698278      0.285816  0.213494          0.955691  0.087036
#
#    speechiness    tempo   valence genre_top
# 0     0.159310  165.922  0.576661   Hip-Hop
# 1     0.461818  126.957  0.269240   Hip-Hop
# 2     0.124595  100.260  0.621661   Hip-Hop
# 3     0.525519  114.290  0.894072   Hip-Hop
# 4     0.051740   90.241  0.034018      Rock
# 5     0.032177   53.758  0.035632      Rock
# 6     0.087527   91.912  0.034325      Rock
# 7     0.053406   94.322  0.028347      Rock
# 8     0.088781   97.880  0.073548      Rock
# 9     0.064094  125.645  0.150599      Rock

# %%
# Inspect the resultant dataframe
echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   acousticness      4802 non-null   float64
#  2   danceability      4802 non-null   float64
#  3   energy            4802 non-null   float64
#  4   instrumentalness  4802 non-null   float64
#  5   liveness          4802 non-null   float64
#  6   speechiness       4802 non-null   float64
#  7   tempo             4802 non-null   float64
#  8   valence           4802 non-null   float64
#  9   genre_top         4802 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %%
# Create a correlation matrix
corr_metrics = echonest_metrics.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row0_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row0_col2 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row0_col3 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row0_col5 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row0_col6 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row0_col7 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row0_col8 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row1_col4 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row1_col5 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row1_col6 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row1_col8 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row2_col0 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row2_col1 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row2_col3 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row2_col4 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row2_col6 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row2_col7 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row2_col8 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row3_col0 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row3_col2 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row3_col4 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row3_col5 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row3_col6 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row3_col7 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row3_col8 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row4_col1 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row4_col2 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row4_col3 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row4_col5 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row4_col7 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row5_col0 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row5_col1 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row5_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row5_col3 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row5_col4 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row5_col6 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row5_col7 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row5_col8 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row6_col0 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row6_col1 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row6_col2 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row6_col3 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row6_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_36ab54e2_9c4f_11eb_8421_c8d9d2838ad4row6_col5 {
#             background-color:  #dedcec;
#             color:  #000000;

# %%
# Define our features
features = echo_tracks.drop(columns=['genre_top', 'track_id']) 
features.head(10)
# Out:
#    acousticness  danceability    energy  instrumentalness  liveness  \
# 0      0.416675      0.675894  0.634476          0.010628  0.177647
# 1      0.374408      0.528643  0.817461          0.001851  0.105880
# 2      0.043567      0.745566  0.701470          0.000697  0.373143
# 3      0.452217      0.513238  0.560410          0.019443  0.096567
# 4      0.988306      0.255661  0.979774          0.973006  0.121342
# 5      0.970135      0.352946  0.023852          0.957113  0.113261
# 6      0.981657      0.142249  0.912122          0.967294  0.363510
# 7      0.989141      0.225978  0.722835          0.263076  0.092371
# 8      0.886660      0.298518  0.744333          0.920950  0.139587
# 9      0.698278      0.285816  0.213494          0.955691  0.087036
#
#    speechiness    tempo   valence
# 0     0.159310  165.922  0.576661
# 1     0.461818  126.957  0.269240
# 2     0.124595  100.260  0.621661
# 3     0.525519  114.290  0.894072
# 4     0.051740   90.241  0.034018
# 5     0.032177   53.758  0.035632
# 6     0.087527   91.912  0.034325
# 7     0.053406   94.322  0.028347
# 8     0.088781   97.880  0.073548
# 9     0.064094  125.645  0.150599

# %%
# Define our labels
labels = echo_tracks['genre_top']
labels.head(10)
# Out:
# 0    Hip-Hop
# 1    Hip-Hop
# 2    Hip-Hop
# 3    Hip-Hop
# 4       Rock
# 5       Rock
# 6       Rock
# 7       Rock
# 8       Rock
# 9       Rock
# Name: genre_top, dtype: object

# %%
# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# %%
# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)
scaled_train_features
# Out:
# array([[-0.19121034,  1.30442004,  0.03831594, ...,  0.37303429,
#          1.15397908,  0.46228696],
#        [-0.30603598,  0.50188641,  0.78817624, ...,  2.44615517,
#          0.00791367, -0.69081137],
#        [-1.20481276,  1.68413943,  0.31285194, ...,  0.13513049,
#         -0.77731688,  0.63107745],
#        ...,
#        [-1.29470431,  1.17682795,  0.13265633, ...,  0.85182206,
#         -0.93541008, -0.07941825],
#        [-1.13869115, -0.02253433,  0.57117905, ...,  1.40951543,
#          1.31301348,  0.47513794],
#        [-0.90611434,  1.10148973,  0.56322452, ...,  1.36030881,
#         -1.43669053,  0.76217464]])

# %%
# This is just to make plots appear in the notebook
# %matplotlib inline
# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_
exp_variance
# Out:
# array([0.24297674, 0.18044316, 0.13650309, 0.12994089, 0.11056248,
#        0.08302245, 0.06923783, 0.04731336])

# %%
# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_), exp_variance)
ax.set_xlabel('Principal Component #')#')
# Out:
# Text(0.5, 0, 'Principal Component #')

# %%
import numpy as np

# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.85.
fig, ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y=0.85, linestyle='--')

# %%
# choose the n_components where about 85% of our variance can be explained
n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)
pca_projection
# Out:
# array([[ 1.59666656,  1.0500117 , -0.01778555,  0.73142514, -0.36832686,
#         -0.71505324],
#        [ 1.58153526,  1.07661327,  1.04346038,  0.16929959, -1.81917099,
#          1.3884574 ],
#        [ 2.01545627,  1.4085176 ,  0.24506524, -1.53545814,  0.62769959,
#         -0.45716338],
#        ...,
#        [ 1.66908628,  1.84010121,  2.38294303, -2.12871589,  1.23664547,
#         -0.63277253],
#        [ 1.17001951,  2.03158181,  0.08689922,  0.88396123, -1.45765649,
#         -0.03590123],
#        [ 2.36368976,  1.15900708,  0.4473735 , -1.35198128, -0.03592518,
#          0.82678557]])

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(
    pca_projection, labels, random_state=10)

# %%
# Train our decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)

# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression

# %%
# Train our logisitic regression
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# %%
# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.77      0.54      0.64       235
#         Rock       0.90      0.96      0.93       966
#
#     accuracy                           0.88      1201
#    macro avg       0.83      0.75      0.78      1201
# weighted avg       0.87      0.88      0.87      1201

# %%
# Subset a balanced proportion of data points
hop_only = echo_tracks.loc[echo_tracks['genre_top'] == 'Hip-Hop']
rock_only = echo_tracks.loc[echo_tracks['genre_top'] == 'Rock']

# subset only the rock songs, and take a sample the same size as there are hip-hop songs
rock_only = rock_only.sample(hop_only.shape[0], random_state=10)

# concatenate the dataframes hop_only and rock_only
rock_hop_bal = pd.concat([rock_only, hop_only])
rock_hop_bal
# Out:
#       track_id  acousticness  danceability    energy  instrumentalness  \
# 773       4038      0.825838      0.263645  0.797948      8.423181e-01
# 2273     19501      0.966635      0.386114  0.651980      8.694723e-01
# 2846     31252      0.721510      0.358035  0.948187      8.011837e-01
# 2147     17947      0.617370      0.487321  0.918848      8.170503e-01
# 2654     27421      0.025464      0.245523  0.422381      9.380106e-01
# ...        ...           ...           ...       ...               ...
# 4797    124718      0.412194      0.686825  0.849309      6.000000e-10
# 4798    124719      0.054973      0.617535  0.728567      7.215700e-06
# 4799    124720      0.010478      0.652483  0.657498      7.098000e-07
# 4800    124721      0.067906      0.432421  0.764508      1.625500e-06
# 4801    124722      0.153518      0.638660  0.762567      5.000000e-10
#
#       liveness  speechiness    tempo   valence genre_top
# 773   0.177089     0.045277  166.580  0.713586      Rock
# 2273  0.353138     0.032208  130.767  0.712374      Rock
# 2846  0.105706     0.095522  125.884  0.208728      Rock
# 2147  0.089908     0.040337  129.565  0.268893      Rock
# 2654  0.441009     0.038795  149.960  0.439876      Rock
# ...        ...          ...      ...       ...       ...
# 4797  0.867543     0.367315   96.104  0.692414   Hip-Hop
# 4798  0.131438     0.243130   96.262  0.399720   Hip-Hop
# 4799  0.701523     0.229174   94.885  0.432240   Hip-Hop
# 4800  0.104412     0.310553  171.329  0.580087   Hip-Hop
# 4801  0.264847     0.303372   77.842  0.656612   Hip-Hop
#
# [1820 rows x 10 columns]

# %%
# The features, labels, and pca projection are created for the balanced dataframe
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# Redefine the train and test set with the pca_projection from the balanced data
train_features, test_features, train_labels, test_labels = train_test_split(
    pca_projection, labels, random_state=10)

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# %%
# compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.74      0.73      0.74       230
#         Rock       0.73      0.74      0.73       225
#
#     accuracy                           0.74       455
#    macro avg       0.74      0.74      0.74       455
# weighted avg       0.74      0.74      0.74       455
#
# Logistic Regression:
#                precision    recall  f1-score   support
#
#      Hip-Hop       0.84      0.80      0.82       230
#         Rock       0.80      0.85      0.83       225
#
#     accuracy                           0.82       455
#    macro avg       0.82      0.82      0.82       455
# weighted avg       0.82      0.82      0.82       455

# %%
from sklearn.model_selection import KFold, cross_val_score

# Set up our K-fold cross-validation
kf = KFold(10)

tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)

# %%
# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv=kf)
logit_score = cross_val_score(logreg, pca_projection, labels, cv=kf)

# Print the mean of each array o scores
print("Decision Tree:", np.mean(tree_score), "Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.7489010989010989 Logistic Regression: 0.782967032967033
